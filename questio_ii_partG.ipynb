# %%
pip install pandas_market_calendars
# Out:
# Collecting pandas_market_calendars
#   Downloading https://files.pythonhosted.org/packages/27/de/ceb494df8a721998d19d256a3d326c7e8a21fd1dafccf25dff7143d15287/pandas_market_calendars-1.6.1-py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 181kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.18 in /opt/anaconda3/lib/python3.7/site-packages (from pandas_market_calendars) (0.25.1)
# Collecting trading-calendars (from pandas_market_calendars)
#   Downloading https://files.pythonhosted.org/packages/8d/07/ea64b7acb14ca7db166d509cd43acc3548c2c2809e94730dfd9bb6546cb4/trading_calendars-2.0.0.tar.gz (102kB)
#      |████████████████████████████████| 112kB 303kB/s eta 0:00:01
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.7/site-packages (from pandas_market_calendars) (2019.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.7/site-packages (from pandas_market_calendars) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.18->pandas_market_calendars) (1.17.2)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.7/site-packages (from trading-calendars->pandas_market_calendars) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil->pandas_market_calendars) (1.12.0)
# Building wheels for collected packages: trading-calendars
#   Building wheel for trading-calendars (setup.py) ... done
#   Created wheel for trading-calendars: filename=trading_calendars-2.0.0-cp37-none-any.whl size=135649 sha256=6ada312551b64f19bb5b05b760f731e272ccfdaaded330673a4d1a91ab44e851
#   Stored in directory: /Users/guillaume/Library/Caches/pip/wheels/6e/fb/89/d71a90b9dd2c51fad1b5f6d240deb0d5051e80402f9fc3a6b9
# Successfully built trading-calendars
# Installing collected packages: trading-calendars, pandas-market-calendars
# Successfully installed pandas-market-calendars-1.6.1 trading-calendars-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/ff/0d/18c590b08f91d14376174bcf1acf96a9d4b35045f7344d046b60444399f2/matplotlib-3.3.3-cp37-cp37m-macosx_10_9_x86_64.whl (8.5MB)
#      |████████████████████████████████| 8.5MB 97kB/s eta 0:00:014     |███████▊                        | 2.0MB 152kB/s eta 0:00:43     |███████████████▏                | 4.0MB 261kB/s eta 0:00:18
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (6.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (1.17.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.7/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied, skipping upgrade: six in /opt/anaconda3/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (41.4.0)
# Installing collected packages: matplotlib
#   Found existing installation: matplotlib 3.1.1
#     Uninstalling matplotlib-3.1.1:
#       Successfully uninstalled matplotlib-3.1.1
# Successfully installed matplotlib-3.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline
import pandas_datareader.data as web 
import datetime
import pandas_market_calendars as mcal
import matplotlib.dates as mdates
import scipy.stats as scs
from sklearn.linear_model import LinearRegression
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf as sm

import os 
CWD = os.getcwd()
path_fig = os.path.join(CWD,'images')
path_table=os.path.join(CWD,'table')
if not os.path.exists(path_fig): os.makedirs(path_fig)
if not os.path.exists(path_table):os.makedirs(path_table)

# %%
start = datetime.datetime(1993, 6, 1) #y,m,d
end = datetime.datetime(2020,4,10)

# %%
swatch=web.DataReader('UHR.SW', 'yahoo', start, end)
nestle= web.DataReader('NESN.SW', 'yahoo', start, end)
smi= web.DataReader('^SSMI','yahoo',start,end)

# %%
swatch_close=swatch['Adj Close']
nestle_close=nestle['Adj Close']
smi_close=smi['Adj Close']

# %%
d={'Swatch_close':swatch_close,'Nestle_close':nestle_close,'Smi_close':smi_close}
df = pd.DataFrame(data=d)

# %%
df = df.dropna()
df.head()
# Out:
#             Swatch_close  Nestle_close    Smi_close
# Date
# 1998-07-17     73.005150      4.082260  8288.200195
# 1998-07-20     73.005150      4.123868  8400.799805
# 1998-07-21     72.330849      4.158342  8412.000000
# 1998-07-22     70.551277      4.084637  8340.700195
# 1998-07-23     68.895172      3.937229  8229.200195

# %%
df.index
nestle_close = df['Nestle_close']
swatch_close = df['Swatch_close']
smi_close = df['Smi_close']

# %%
###in 2 axis en pct
##plot in seaborn with 2 axis 
sns.lineplot(df.resample('Y').mean().index,df['Nestle_close'].resample('Y').mean(), label='Nestle Adj. close',c='r')
sns.lineplot(df.resample('Y').mean().index,df['Swatch_close'].resample('Y').mean(),label='Swatch Adj.Close',c='y')
plt.title('Nestle,Swatch & SMI ')
plt.xlabel('Years')
plt.ylabel('Adj.close')
plt.legend()


ax2 = plt.twinx()
sns.lineplot(df.resample('Y').mean().index,df['Smi_close'].resample('Y').mean(), ax=ax2,label= 'SMI CLose', c='c')
ax2.legend(loc="upper right")

plt.savefig(os.path.join(path_fig,'SMI_SWATCH,_NESTLE_yearly.png'));

# %%
###in 2 axis en pct
##plot in seaborn with 2 axis 
sns.lineplot(df.index,nestle_close, label='Nestle Adj. close',c='r')
sns.lineplot(df.index,swatch_close,label='Swatch Adj.Close',c='y')
plt.title('Nestle,Swatch & SMI ')
plt.xlabel('Years')
plt.ylabel('Adj.close')
plt.legend()


ax2 = plt.twinx()
sns.lineplot(df.index,smi_close, ax=ax2,label= 'SMI CLose', c='c')
ax2.legend(loc="upper right")

plt.savefig(os.path.join(path_fig,'SMI_SWATCH,_NESTLE.png'));

# %%
#stock plot
sns.lineplot(df.index,nestle_close, label='Nestle Adj. close')
sns.lineplot(df.index,swatch_close,label='Swatch Adj.Close')
plt.title('Nestle,Swatch & SMI ')
plt.xlabel('Years')
plt.ylabel('Adj.close')
plt.legend()
plt.savefig(os.path.join(path_fig,'SWATCH,_NESTLE.png'))

# %%
#stock plot 2 axes
ax2=plt.twinx()

sns.lineplot(df.index,nestle_close, label='Nestle Adj. close')
sns.lineplot(df.index,swatch_close,label='Swatch Adj.Close',ax=ax2)

plt.title('Nestle,Swatch & SMI ')
plt.xlabel('Years')
plt.ylabel('Adj.close')
plt.legend()
plt.savefig(os.path.join(path_fig,'2ax_SWATCH,_NESTLE.png'))

# %%
#smi plot
sns.lineplot(df.index,smi_close, label='SMI Adj. close')
plt.title('SMI ')
plt.xlabel('Years')
plt.ylabel('Adj.close')
plt.legend()
plt.savefig(os.path.join(path_fig,'SMI.png'))

# %%
sns.set(style="ticks")
def hide_current_axis(*args, **kwds):
    plt.gca().set_visible(False)

# %%
pairplot=sns.pairplot(df_drop[['Return SMI','Return Swatch','Return Nestle']].resample("1Y").mean(), diag_kind=('kde'))
pairplot.fig.suptitle("PairPlot SMI, Swatch & Nestle")
pairplot.map_upper(hide_current_axis)
plt.savefig(os.path.join(path_fig,'Pairplot_return_yearly.png'))

# %%
#Returns
df['Return SMI']=df['Smi_close'].pct_change()
df['Return Swatch']=df['Swatch_close'].pct_change()
df['Return Nestle']=df['Nestle_close'].pct_change()

#log return
df['log Return SMI'] = np.log(df['Smi_close']/df['Smi_close'].shift(1))
df['log return Swatch']=np.log(df['Swatch_close'] / df['Swatch_close'].shift(1))
df['log Return Nestle'] = np.log(df['Nestle_close']/df['Nestle_close'].shift(1))

df.head(3)
# Out:
#             Swatch_close  Nestle_close    Smi_close  Return SMI  \
# Date
# 1998-07-17     73.005150      4.082260  8288.200195         NaN
# 1998-07-20     73.005150      4.123868  8400.799805    0.013586
# 1998-07-21     72.330849      4.158342  8412.000000    0.001333
#
#             Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# Date
# 1998-07-17            NaN            NaN             NaN                NaN
# 1998-07-20       0.000000       0.010192        0.013494           0.000000
# 1998-07-21      -0.009236       0.008360        0.001332          -0.009279
#
#             log Return Nestle
# Date
# 1998-07-17                NaN
# 1998-07-20           0.010141
# 1998-07-21           0.008325

# %%
df.head()
stock_close=df[['Swatch_close','Nestle_close','Smi_close']]
return_stock=df[['Return SMI','Return Swatch','Return Nestle']]

# %%
#heatmap / correlation stock
plt.figure(figsize=(16, 10))
matrix = np.triu(stock_close.resample('Y').mean().corr())
heat=sns.heatmap(stock_close.resample('Y').mean().corr(), annot=True,fmt='.1g',vmin=-1, vmax=1, center= 0, mask=matrix)
plt.title('Correlation of stock prices')
plt.savefig(os.path.join(path_fig,'heat_stock.png'))

# %%
#heatmap / correlation return
plt.figure(figsize=(5, 2))
matrix = np.triu(return_stock.corr())
heat=sns.heatmap(return_stock.corr(), annot=True,fmt='.1g',vmin=-1, vmax=1, center= 0)
plt.title('Correlation of return')
#plt.savefig(os.path.join(path_fig,'heat_returb.png'))
# Out:
# Text(0.5, 1, 'Correlation of return')

# %%
x=df['Swatch_close']
y=df['Smi_close']
m, b = np.polyfit(x, y, 1) ### create reg
plt.plot(x, m*x + b,'r')

scatter_SMI_SWATCH=sns.scatterplot(data=df, x='Swatch_close', y="Smi_close")

plt.savefig(os.path.join(path_fig,'Scatter_SMI_Swatch.png'))

# %%
x=df['Nestle_close']
y=df['Smi_close']
m, b = np.polyfit(x, y, 1) ### create reg
plt.plot(x, m*x + b,'r')

scatter_SMI_Nestle=sns.scatterplot(data=df, x='Nestle_close', y="Smi_close")
plt.savefig(os.path.join(path_fig,'Scatter_SMI_Nestle.png'))

# %%
x=df['Nestle_close']
y=df['Swatch_close']
m, b = np.polyfit(x, y, 1) ### create reg
plt.plot(x, m*x + b,'r')

scatter_Nestle_Swatch=sns.scatterplot(data=df, x='Nestle_close', y="Swatch_close")
plt.savefig(os.path.join(path_fig,'Scatter_Nestle_Swatch.png'))

# %%
x=df['Nestle_close']
y=df['Swatch_close']
m, b = np.polyfit(x, y, 1) ### create reg
plt.plot(x, m*x + b,'r')

scatter_HUE_Nestle_Swatch=sns.scatterplot(data=df, x='Nestle_close', y="Swatch_close", hue='Smi_close');
plt.savefig(os.path.join(path_fig,'Scatter_HUE_Nestle_Swatch.png'))

# %%
#scatter of return
log_return=df[['log Return SMI','log return Swatch','log Return Nestle']]
pairplot_log_return = sns.pairplot(log_return, diag_kind=('kde'))
pairplot.fig.suptitle("PairPlot  log Return SMI, Swatch & Nestle")
plt.savefig(os.path.join(path_fig,'Pairplot_log_return.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
#subplot Return & log return nestle 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('Density for Nestle')

ax1.hist(df['Nestle_close'],bins=70)
ax1.set_title("Density Nestle Close")

ax2.hist(df['Return Nestle'], bins=100)
ax2.set_title("Density Neslte Return");

ax3.hist(df_drop['log Return Nestle'], bins=70)
ax3.set_title("Density log Neslte Return")

plt.savefig(os.path.join(path_fig,'Density of Nestle.png'))

# %%
#subplot Return & log return SMI
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('Density for SMI')

ax1.hist(df['Smi_close'],bins=70)
ax1.set_title("Density Smi Close")

ax2.hist(df['Return SMI'], bins=70)
ax2.set_title("Density Neslte Smi");

ax3.hist(df['log Return SMI'], bins=70)
ax3.set_title("Density log Smi Return")

plt.savefig(os.path.join(path_fig,'Density SMI.png'))

# %%
#subplot Return & log return Swatch
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('Density for Swatch')

ax1.hist(df['Swatch_close'],bins=70)
ax1.set_title("Density Swatch Close")

ax2.hist(df['Return Swatch'], bins=70)
ax2.set_title("Density Return Swatch");

ax3.hist(df['log Return SMI'], bins=70)
ax3.set_title("Density log Swatch Return")

plt.savefig(os.path.join(path_fig,'Density Swatch.png'))

# %%
#subplot Return & log return Swatch
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('Density for Returns')

ax1.hist(df_drop['Return Swatch'],bins=70)
ax1.set_title("Density Swatch Return")

ax2.hist(df_drop['Return Nestle'], bins=70)
ax2.set_title("Density Nestle Return");

ax3.hist(df_drop['Return SMI'], bins=70)
ax3.set_title("Density SMI Return")

#plt.savefig(os.path.join(path_fig,'Density return.png'))
# Out:
# Text(0.5, 1.0, 'Density SMI Return')

# %%
#empirical distribution and the CDF for Swatch stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Swatch_close'], n_bins, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for SWatch')
ax.set_xlabel('Stock Price')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CFD Swatch prices.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
sns.distplot(df['Swatch_close'].values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True})

# %%
sns.distplot(df['Return Swatch'].dropna().values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True},label='Empirical')
plt.legend(loc='left')
plt.title('Cumulative step histograms & CDF for Swatch')
plt.xlabel('Stock Price')
plt.ylabel('Likelihood of occurrence')
plt.savefig(os.path.join(path_fig,'CDF Swatch return.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
sns.distplot(df_drop['Return Nestle'].dropna().values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True},label="Empirical")
plt.legend(loc='left')
plt.title('Cumulative step histograms & CDF for Nestle')
plt.xlabel('Stock Price')
plt.ylabel('Likelihood of occurrence')
plt.savefig(os.path.join(path_fig,'CDF Nestle return.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
sns.distplot(df['Return SMI'].dropna().values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True},label='Empirical')
plt.legend(loc='left')
plt.title('Cumulative step histograms & CDF for SMI')
plt.xlabel('Stock Price')
plt.ylabel('Likelihood of occurrence')
plt.savefig(os.path.join(path_fig,'CDF SMI return.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
fig = plt.figure(figsize=(10,6))
sns.distplot(df['Nestle_close'].values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True})
fig.legend(labels=['test_label1'])
plt.setp(axes, yticks=[])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1549         try:
# -> 1550             ret = self.converter.convert(x, self.units, self)
#    1551         except Exception as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51             raise ValueError(
# ---> 52                 'Missing category information for StrCategoryConverter; '
#      53                 'this might be caused by unintendedly mixing categorical and '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-226-677f7c64d305> in <module>
#       2 sns.distplot(df['Nestle_close'].values, hist_kws={'cumulative': True, 'density': True}, kde_kws={'cumulative': True})
#       3 fig.legend(labels=['test_label1'])
# ----> 4 plt.setp(axes, yticks=[])
#       5 plt.tight_layout()
#       6 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in setp(obj, *args, **kwargs)
#     361 @docstring.copy(_setp)
#     362 def setp(obj, *args, **kwargs):
# --> 363     return _setp(obj, *args, **kwargs)
#     364
#     365
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in setp(obj, *args, **kwargs)
#    1572     # put args into ordereddict to maintain order
#    1573     funcvals = OrderedDict((k, v) for k, v in zip(args[::2], args[1::2]))
# -> 1574     ret = [o.update(funcvals) for o in objs] + [o.set(**kwargs) for o in objs]
#    1575     return list(cbook.flatten(ret))
#    1576
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1572     # put args into ordereddict to maintain order
#    1573     funcvals = OrderedDict((k, v) for k, v in zip(args[::2], args[1::2]))
# -> 1574     ret = [o.update(funcvals) for o in objs] + [o.set(**kwargs) for o in objs]
#    1575     return list(cbook.flatten(ret))
#    1576
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1069             sorted(kwargs.items(), reverse=True,
#    1070                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1071         return self.update(props)
#    1072
#    1073     def findobj(self, match=None, include_self=True):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     969                     raise AttributeError('{!r} object has no property {!r}'
#     970                                          .format(type(self).__name__, k))
# --> 971                 return func(v)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_yticks(self, ticks, minor)
#    3728             Default is ``False``.
#    3729         """
# -> 3730         ret = self.yaxis.set_ticks(ticks, minor=minor)
#    3731         return ret
#    3732
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1749         """
#    1750         # XXX if the user changes units, the information will be lost here
# -> 1751         ticks = self.convert_units(ticks)
#    1752         if len(ticks) > 1:
#    1753             xleft, xright = self.get_view_interval()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1551         except Exception as e:
#    1552             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1553                                          f'units: {x!r}') from e
#    1554         return ret
#    1555
#
# ConversionError: Failed to convert value(s) to axis units: []

# %%
#empirical distribution and the CDF for SMI stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Smi_close'], n_bins, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for SMI')
ax.set_xlabel('Stock Price')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CDF SMI prices.png'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
#empirical distribution and the CDF for SMI stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Nestle_close'], n_bins, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for Nestle Price')
ax.set_xlabel('Stock Price')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CDF Nestle price.png'))

# %%
#empirical distribution and the CDF of Return

# %%
#empirical distribution and the CDF for SMI stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Return SMI'], density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for SMI returns')
ax.set_xlabel('Return')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CDF return SMI'))

# %%
#empirical distribution and the CDF for SMI stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Return Swatch'], density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for Nestle')
ax.set_xlabel('Return')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CDF return Swatch'))

# %%
#empirical distribution and the CDF for SMI stock prices
fig, ax = plt.subplots(figsize=(8, 4))

n_bins = 70

# plot the cumulative histogram
n, bins, patches = ax.hist(df['Return Nestle'], density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the CDF Normal distribution.
mu = 0
sigma = 1
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms (CDF) for Nestle Return')
ax.set_xlabel('Return')
ax.set_ylabel('Likelihood of occurrence')

plt.savefig(os.path.join(path_fig,'CDF return Nestle'))

# %%
# Subtplot CDF Close
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('CDF Stock RETURN')

ax1.hist(df['Return Nestle'], density=True, histtype='step',cumulative=True, label='Empirical')
ax1.set_title("CDF Nestle Return")

ax2.hist(df['Return Swatch'], density=True, histtype='step',cumulative=True, label='Empirical')
ax2.set_title("CDF Swatch Return")

ax3.hist(df['Return SMI'], density=True, histtype='step',cumulative=True, label='Empirical')
ax3.set_title("CDF SMI return");

plt.savefig(os.path.join(path_fig,'Subplot CDF 3 stock Return'))

# %%
#subplot CDF return
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle('CDF Stock Price')

ax1.hist(df['Nestle_close'], density=True, histtype='step',cumulative=True, label='Empirical')
ax1.set_title("Density Nestle close")

ax2.hist(df['Swatch_close'], density=True, histtype='step',cumulative=True, label='Empirical')
ax2.set_title("Density Swatch Close");

ax3.hist(df['Smi_close'], density=True, histtype='step',cumulative=True, label='Empirical')
ax3.set_title("Density SMI Close");

plt.savefig(os.path.join(path_fig,'CF 3 stock prices'))

# %%
df['Date']=pd.to_datetime(df.index)

# %%
df = df[['Date','Swatch_close', 'Nestle_close', 'Smi_close', 'Return SMI',
       'Return Swatch', 'Return Nestle', 'log Return SMI', 'log return Swatch',
       'log Return Nestle']]

# %%
df.head()
# Out:
#                  Date  Swatch_close  Nestle_close    Smi_close  Return SMI  \
# Date
# 2009-01-05 2009-01-05    121.958183     29.141609  5756.089844         NaN
# 2009-01-06 2009-01-06    123.627731     29.141609  5799.310059    0.007509
# 2009-01-07 2009-01-07    123.309753     29.169106  5761.689941   -0.006487
# 2009-01-08 2009-01-08    117.267487     28.907934  5751.069824   -0.001843
# 2009-01-09 2009-01-09    113.689819     27.753267  5697.240234   -0.009360
#
#             Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# Date
# 2009-01-05            NaN            NaN             NaN                NaN
# 2009-01-06       0.013690       0.000000        0.007481           0.013597
# 2009-01-07      -0.002572       0.000944       -0.006508          -0.002575
# 2009-01-08      -0.049001      -0.008954       -0.001845          -0.050242
# 2009-01-09      -0.030509      -0.039943       -0.009404          -0.030984
#
#             log Return Nestle
# Date
# 2009-01-05                NaN
# 2009-01-06           0.000000
# 2009-01-07           0.000943
# 2009-01-08          -0.008994
# 2009-01-09          -0.040763

# %%
# Out:
# Index(['Swatch_close', 'Nestle_close', 'Smi_close', 'Return SMI',
#        'Return Swatch', 'Return Nestle', 'log Return SMI', 'log return Swatch',
#        'log Return Nestle', 'Date'],
#       dtype='object')

# %%
#new df for yearly data based on mean 
df_y = df.resample('Y').mean()

# %%
df_y.head()
# Out:
#             Swatch_close  Nestle_close    Smi_close  Return SMI  \
# Date
# 1998-12-31     51.762906      3.404251  6866.769235   -0.001003
# 1999-12-31     71.414476      3.364878  7130.881822    0.000281
# 2000-12-31    149.203695      3.917275  7706.406359    0.000330
# 2001-12-31    122.043806      4.214639  6944.329307   -0.000845
# 2002-12-31     99.036921      4.648632  5720.443068   -0.001124
#
#             Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# Date
# 1998-12-31      -0.002494      -0.000915       -0.001261          -0.002901
# 1999-12-31       0.003692      -0.000011        0.000220           0.003460
# 2000-12-31       0.000965       0.033745        0.000286           0.000646
# 2001-12-31      -0.000741      -0.000142       -0.000952          -0.001159
# 2002-12-31      -0.000548       0.000199       -0.001290          -0.001003
#
#             log Return Nestle
# Date
# 1998-12-31          -0.001194
# 1999-12-31          -0.000098
# 2000-12-31           0.001028
# 2001-12-31          -0.000263
# 2002-12-31          -0.000021

# %%
#export describe table
describe_daily=df.describe()
describe_yearly=df_y.describe()
describe_daily.to_excel(os.path.join(path_table,'Describe_daily.xlsx'))
describe_yearly.to_excel(os.path.join(path_table,'Describe_yearly.xlsx'))

# %%
df.describe()
# Out:
#        Swatch_close  Nestle_close     Smi_close   Return SMI  Return Swatch  \
# count   5461.000000   5461.000000   5461.000000  5460.000000    5460.000000
# mean     234.651272     35.415034   7348.138884     0.000096       0.000401
# std      120.392554     28.658745   1435.629902     0.012000       0.021053
# min       39.692879      0.382786   3675.399902    -0.096374      -0.163457
# 25%      125.313263      5.868557   6236.799805    -0.005490      -0.010516
# 50%      234.418228     31.987049   7373.399902     0.000493       0.000000
# 75%      325.848907     59.190041   8554.509766     0.005997       0.011178
# max      514.693665    110.331757  11263.009766     0.113910       0.132353
#
#        Return Nestle  log Return SMI  log return Swatch  log Return Nestle
# count    5460.000000     5460.000000        5460.000000        5460.000000
# mean        0.002204        0.000024           0.000179           0.000585
# std         0.125158        0.012015           0.021074           0.046626
# min        -0.900000       -0.101339          -0.178478          -2.302585
# 25%        -0.005664       -0.005505          -0.010572          -0.005680
# 50%         0.000000        0.000493           0.000000           0.000000
# 75%         0.006590        0.005979           0.011116           0.006568
# max         9.133536        0.107876           0.124298           2.315850

# %%
df_na = df.dropna()
df_na
# Out:
#             Swatch_close  Nestle_close    Smi_close  Return SMI  \
# Date
# 1998-07-20     73.005150      4.123868  8400.799805    0.013586
# 1998-07-21     72.330849      4.158342  8412.000000    0.001333
# 1998-07-22     70.551277      4.084637  8340.700195   -0.008476
# 1998-07-23     68.895172      3.937229  8229.200195   -0.013368
# 1998-07-24     70.122139      3.799332  8205.700195   -0.002856
# ...                  ...           ...          ...         ...
# 2020-04-03    176.530884     99.766418  9242.440430   -0.003076
# 2020-04-06    189.454865    101.325882  9462.339844    0.023792
# 2020-04-07    196.134674    101.267403  9514.599609    0.005523
# 2020-04-08    195.360199    101.559799  9432.389648   -0.008640
# 2020-04-09    194.488922     99.629967  9452.830078    0.002167
#
#             Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# Date
# 1998-07-20       0.000000       0.010192        0.013494           0.000000
# 1998-07-21      -0.009236       0.008360        0.001332          -0.009279
# 1998-07-22      -0.024603      -0.017725       -0.008512          -0.024911
# 1998-07-23      -0.023474      -0.036088       -0.013458          -0.023754
# 1998-07-24       0.017809      -0.035024       -0.002860           0.017652
# ...                   ...            ...             ...                ...
# 2020-04-03      -0.030569       0.012663       -0.003081          -0.031046
# 2020-04-06       0.073211       0.015631        0.023514           0.070655
# 2020-04-07       0.035258      -0.000577        0.005508           0.034651
# 2020-04-08      -0.003949       0.002887       -0.008678          -0.003957
# 2020-04-09      -0.004460      -0.019002        0.002165          -0.004470
#
#             log Return Nestle
# Date
# 1998-07-20           0.010141
# 1998-07-21           0.008325
# 1998-07-22          -0.017884
# 1998-07-23          -0.036756
# 1998-07-24          -0.035652
# ...                       ...
# 2020-04-03           0.012584
# 2020-04-06           0.015510
# 2020-04-07          -0.000577
# 2020-04-08           0.002883
# 2020-04-09          -0.019185
#
# [5460 rows x 9 columns]

# %%
describe_yearly
# Out:
#        Swatch_close  Nestle_close     Smi_close  Return SMI  Return Swatch  \
# count     23.000000     23.000000     23.000000   23.000000      23.000000
# mean     230.348971     36.771905   7429.577481    0.000024       0.000202
# std      120.245503     31.095252   1445.525430    0.000759       0.001744
# min       51.762906      3.364878   4836.031608   -0.001456      -0.003718
# 25%      128.508374      6.078254   6390.940246   -0.000312      -0.000699
# 50%      221.643795     30.330047   7130.881822    0.000177       0.000620
# 75%      327.528480     59.886449   8739.983144    0.000600       0.001230
# max      469.765725    100.643895  10112.864355    0.001147       0.003692
#
#        Return Nestle  log Return SMI  log return Swatch  log Return Nestle
# count      23.000000       23.000000          23.000000          23.000000
# mean        0.002053       -0.000059          -0.000033           0.000515
# std         0.006950        0.000824           0.001825           0.000761
# min        -0.000915       -0.001702          -0.004223          -0.001194
# 25%         0.000115       -0.000374          -0.001041           0.000012
# 50%         0.000531        0.000145           0.000495           0.000491
# 75%         0.001130        0.000571           0.001047           0.000982
# max         0.033745        0.001129           0.003460           0.002197

# %%
from scipy.stats import describe
df_y_desc = describe(df_na, axis=0)
df2 = pd.DataFrame([df_y_desc.kurtosis, df_y_desc.skewness], columns=df_na.columns,index=['Kurtosis', 'Skewness'])
df2
# Out:
#           Swatch_close  Nestle_close  Smi_close  Return SMI  Return Swatch  \
# Kurtosis     -0.893335     -0.735046  -0.813243    7.246905       3.591022
# Skewness      0.358412      0.546403  -0.013294   -0.117368      -0.011207
#
#           Return Nestle  log Return SMI  log return Swatch  log Return Nestle
# Kurtosis    5188.725487        7.198843           3.813641        2202.647303
# Skewness      71.089120       -0.282349          -0.190895           0.506120

# %%
def statDescriptive(data):
    data = data.dropna()
    data_describ = data.describe()
    
    data_stat = describe(data, axis=0)
    df2 = pd.DataFrame([data_stat.kurtosis, data_stat.skewness], columns=data.columns,index=['Kurtosis', 'Skewness'])
    
    data_describ = data_describ.append(df2)
    
    return data_describ

# %%
def information_ratio(returns, benchmark_returns, days):
     return_difference = returns - benchmark_returns
     volatility = return_difference.std() * np.sqrt(days)
     information_ratio = return_difference.mean() / volatility
     return information_ratio

# %%
information_ratio(df['Return Swatch'],df['Return SMI'],len(df['Return Swatch']))
# Out:
# 0.0002492884609882098

# %%
statDescriptive(df)
# Out:
#           Swatch_close  Nestle_close     Smi_close   Return SMI  \
# count      5460.000000   5460.000000   5460.000000  5460.000000
# mean        234.680877     35.420773   7347.966712     0.000096
# std         120.383698     28.658232   1435.705002     0.012000
# min          39.692879      0.382786   3675.399902    -0.096374
# 25%         125.325033      5.868557   6236.774902    -0.005490
# 50%         234.535027     32.007666   7373.349854     0.000493
# 75%         325.851822     59.190041   8554.512207     0.005997
# max         514.693665    110.331757  11263.009766     0.113910
# Kurtosis     -0.893335     -0.735046     -0.813243     7.246905
# Skewness      0.358412      0.546403     -0.013294    -0.117368
#
#           Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# count       5460.000000    5460.000000     5460.000000        5460.000000
# mean           0.000401       0.002204        0.000024           0.000179
# std            0.021053       0.125158        0.012015           0.021074
# min           -0.163457      -0.900000       -0.101339          -0.178478
# 25%           -0.010516      -0.005664       -0.005505          -0.010572
# 50%            0.000000       0.000000        0.000493           0.000000
# 75%            0.011178       0.006590        0.005979           0.011116
# max            0.132353       9.133536        0.107876           0.124298
# Kurtosis       3.591022    5188.725487        7.198843           3.813641
# Skewness      -0.011207      71.089120       -0.282349          -0.190895
#
#           log Return Nestle
# count           5460.000000
# mean               0.000585
# std                0.046626
# min               -2.302585
# 25%               -0.005680
# 50%                0.000000
# 75%                0.006568
# max                2.315850
# Kurtosis        2202.647303
# Skewness           0.506120

# %%
df_drop = df.drop(df[df["Return Nestle"] ==  df["Return Nestle"].max()].index)
df_drop = df_drop.drop(df_drop[df_drop["Return Nestle"] ==  df_drop["Return Nestle"].min()].index)

# %%
statDescriptive(df_drop)
# Out:
#           Swatch_close  Nestle_close     Smi_close   Return SMI  \
# count      5458.000000   5458.000000   5458.000000  5458.000000
# mean        234.711457     35.432971   7347.801877     0.000094
# std         120.395151     28.656375   1435.941995     0.012002
# min          39.692879      2.785305   3675.399902    -0.096374
# 25%         125.317186      5.878037   6236.725098    -0.005495
# 50%         234.694489     32.036875   7372.699951     0.000493
# 75%         325.857651     59.190041   8554.517090     0.005996
# max         514.693665    110.331757  11263.009766     0.113910
# Kurtosis     -0.893814     -0.735238     -0.813895     7.246204
# Skewness      0.357801      0.546012     -0.012960    -0.117015
#
#           Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# count       5458.000000    5458.000000     5458.000000        5458.000000
# mean           0.000399       0.000696        0.000022           0.000177
# std            0.021056       0.015465        0.012017           0.021077
# min           -0.163457      -0.076672       -0.101339          -0.178478
# 25%           -0.010534      -0.005661       -0.005510          -0.010590
# 50%            0.000000       0.000000        0.000493           0.000000
# 75%            0.011174       0.006589        0.005978           0.011112
# max            0.132353       0.306075        0.107876           0.124298
# Kurtosis       3.589585     112.228869        7.198029           3.812087
# Skewness      -0.010910       6.307068       -0.282001          -0.190579
#
#           log Return Nestle
# count           5458.000000
# mean               0.000583
# std                0.014846
# min               -0.079771
# 25%               -0.005677
# 50%                0.000000
# 75%                0.006567
# max                0.267026
# Kurtosis          81.158532
# Skewness           4.847680

# %%
df_drop[["Return Swatch", "Return Nestle","Return SMI"]].dropna().cov()
print(df_drop[["Return Swatch", "Return Nestle","Return SMI"]].dropna().cov().to_latex(index=False))
# Out:
# \begin{tabular}{rrr}
# \toprule
#  Return Swatch &  Return Nestle &  Return SMI \\
# \midrule
#       0.000443 &       0.000109 &    0.000156 \\
#       0.000109 &       0.000239 &    0.000107 \\
#       0.000156 &       0.000107 &    0.000144 \\
# \bottomrule
# \end{tabular}

# %%
df_drop[["Swatch_close", "Nestle_close","Smi_close"]].dropna().cov()
print(df_drop[["Swatch_close", "Nestle_close","Smi_close"]].dropna().cov().to_latex(index=False))
# Out:
#               Swatch_close  Nestle_close     Smi_close
# Swatch_close  14497.126646   2547.202755  9.238915e+04
# Nestle_close   2547.202755    821.217418  2.764991e+04
# Smi_close     92389.150607  27649.908965  2.061714e+06

# %%
Covariance = np.cov(df_drop["Return Swatch"].values, df_drop["Return Nestle"].values, bias=True)
print(Covariance)
# Out:
# [[nan nan]
#  [nan nan]]

# %%
#scatter of return
log_return=df_drop[['log Return SMI','log return Swatch','log Return Nestle']]
pairplot_log_return = sns.pairplot(log_return, diag_kind=('kde'))
pairplot.fig.suptitle("PairPlot  log Return SMI, Swatch & Nestle")
plt.savefig(os.path.join(path_fig,'Pairplot_log_return.png'))

# %%
df_drop['Return Swatch'].plot()

# %%
ig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (14,4))
fig.suptitle("Daily Return")

ax1.plot(df_drop.index,df_drop['Return SMI'],label='Return Nestle')
ax1.set_title("Daily Return SMI ")

ax2.plot(df_drop.index,df_drop['Return Nestle'],label='Return Nestle')
ax2.set_title("Daily Return Nestle")

ax3.plot(df_drop.index,df_drop['Return Swatch'],label='Return Swatch')
ax3.set_title("Daily Return Swatch")


plt.savefig(os.path.join(path_fig,'CF 3 stock prices daily'))

# %%
print(df_drop[['Return SMI','Return Swatch','Return Nestle']].describe().to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &   Return SMI &  Return Swatch &  Return Nestle \\
# \midrule
# count &  5458.000000 &    5458.000000 &    5458.000000 \\
# mean  &     0.000094 &       0.000399 &       0.000696 \\
# std   &     0.012002 &       0.021056 &       0.015465 \\
# min   &    -0.096374 &      -0.163457 &      -0.076672 \\
# 25\%   &    -0.005495 &      -0.010534 &      -0.005661 \\
# 50\%   &     0.000493 &       0.000000 &       0.000000 \\
# 75\%   &     0.005996 &       0.011174 &       0.006589 \\
# max   &     0.113910 &       0.132353 &       0.306075 \\
# \bottomrule
# \end{tabular}

# %%
print(df_drop[['Return SMI','Return Swatch','Return Nestle']].resample("1Y").mean().describe().to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  Return SMI &  Return Swatch &  Return Nestle \\
# \midrule
# count &   23.000000 &      23.000000 &      23.000000 \\
# mean  &    0.000022 &       0.000200 &       0.000633 \\
# std   &    0.000758 &       0.001743 &       0.000759 \\
# min   &   -0.001456 &      -0.003718 &      -0.000915 \\
# 25\%   &   -0.000312 &      -0.000699 &       0.000115 \\
# 50\%   &    0.000177 &       0.000620 &       0.000531 \\
# 75\%   &    0.000600 &       0.001230 &       0.001053 \\
# max   &    0.001147 &       0.003692 &       0.002362 \\
# \bottomrule
# \end{tabular}

# %%
descr_daily = df.describe()
descr_daily = descr_daily.append(df2)
descr_daily
# Out:
#           Swatch_close  Nestle_close     Smi_close   Return SMI  \
# count      5461.000000   5461.000000   5461.000000  5460.000000
# mean        234.651272     35.415034   7348.138884     0.000096
# std         120.392554     28.658745   1435.629902     0.012000
# min          39.692879      0.382786   3675.399902    -0.096374
# 25%         125.313263      5.868557   6236.799805    -0.005490
# 50%         234.418228     31.987049   7373.399902     0.000493
# 75%         325.848907     59.190041   8554.509766     0.005997
# max         514.693665    110.331757  11263.009766     0.113910
# Kurtosis     -0.893335     -0.735046     -0.813243     7.246905
# Skewness      0.358412      0.546403     -0.013294    -0.117368
#
#           Return Swatch  Return Nestle  log Return SMI  log return Swatch  \
# count       5460.000000    5460.000000     5460.000000        5460.000000
# mean           0.000401       0.002204        0.000024           0.000179
# std            0.021053       0.125158        0.012015           0.021074
# min           -0.163457      -0.900000       -0.101339          -0.178478
# 25%           -0.010516      -0.005664       -0.005505          -0.010572
# 50%            0.000000       0.000000        0.000493           0.000000
# 75%            0.011178       0.006590        0.005979           0.011116
# max            0.132353       9.133536        0.107876           0.124298
# Kurtosis       3.591022    5188.725487        7.198843           3.813641
# Skewness      -0.011207      71.089120       -0.282349          -0.190895
#
#           log Return Nestle
# count           5460.000000
# mean               0.000585
# std                0.046626
# min               -2.302585
# 25%               -0.005680
# 50%                0.000000
# 75%                0.006568
# max                2.315850
# Kurtosis        2202.647303
# Skewness           0.506120

# %%
df.columns
# Out:
# Index(['Date', 'Swatch_close', 'Nestle_close', 'Smi_close', 'Return SMI',
#        'Return Swatch', 'Return Nestle', 'log Return SMI', 'log return Swatch',
#        'log Return Nestle'],
#       dtype='object')

# %%
# subtplot acf daily
fig, axes = plt.subplots(3,1,figsize=(15,10))
fig.title='ACF Daily Return'

fig_first = plot_acf(df['Return SMI'].dropna(),lags= 10, ax=axes[0],title='ACF SMI Daily Return')
fig_second = plot_acf(df['Return Swatch'].dropna(),lags= 10, ax=axes[1],title='ACF Swatch Daily Return')
fig_third = plot_acf(df['Return Nestle'].dropna(),lags= 10, ax=axes[2],title='ACF Nestle Daily Return')

plt.savefig(os.path.join(path_fig,'ACF 3 daily Return'))

# %%
# subtplot acf yearly 
fig, axes = plt.subplots(3,1,figsize=(15,10))
fig.title='ACF Daily Return'

fig_first = plot_acf(df_y['Return SMI'].dropna(),lags= 10, ax=axes[0],title='ACF SMI Yearly Return')
fig_second = plot_acf(df_y['Return Swatch'].dropna(),lags= 10, ax=axes[1],title='ACF Swatch Yearly Return')
fig_third = plot_acf(df_y['Return Nestle'].dropna(),lags= 10,ax=axes[2],title='ACF Nestle Yearly Return')

plt.savefig(os.path.join(path_fig,'ACF 3 Yearly Return'))

# %%
#2d) Rolling correlation for  daily and yearly Price Nestle & Swatch (10)
rolling_corr_daily=df['Swatch_close'].rolling(7).corr(df['Nestle_close'])
rolling_corr_yearly= df_y['Swatch_close'].rolling(10).corr(df_y['Nestle_close'])

# %%
#daily rolling corr windows of 10
fig, axes = plt.subplots(3,1,figsize=(15,10))
sns.lineplot(df.index,rolling_corr_daily, ax=axes[0],label='Rolling correlation (7 days)',c='y')
sns.lineplot(df.index,df['Swatch_close'].rolling(30).corr(df['Nestle_close']), ax=axes[1],label='Rolling correlation (30 days)',c='b')
sns.lineplot(df.index,df['Swatch_close'].rolling(365).corr(df['Nestle_close']), ax=axes[2],label='Rolling correlation (365 days)',c='r')
#plt.title('Rolling correlation (10 days)')
plt.legend()
plt.savefig(os.path.join(path_fig,'rolling_correlation'))

# %%
#daily rolling corr windows of 10
sns.lineplot(df.index,df['Swatch_close'].rolling(365).corr(df['Nestle_close']),label='Rolling correlation (10 days)',c='y')
plt.title('Rolling correlation (10 days)')
plt.xlabel('Years')
plt.ylabel('correlation')
plt.legend()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py:784: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   line, = ax.plot([], [], **kws)
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py:795: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   line, = ax.plot(x, y, **kws)

# %%
#yearly rolling corr windows of 10years
sns.lineplot(df_y.index,rolling_corr_yearly,label='Rolling correlation (10 years)',c='y')
plt.title('Rolling correlation (10 years)')
plt.xlabel('Years')
plt.ylabel('correlation')
plt.legend()

# %%
reg_data = df[['Return Swatch','Return Nestle','Return SMI']]
reg_data['Return SMI t-1'] = reg_data['Return SMI'].shift(1)
reg_data['Return Swatch t-1'] = df['Return Swatch'].shift(1)
reg_data['Return Nestle t-1'] = df['Return Nestle'].shift(1)
reg_data = reg_data.dropna()
reg_data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             Return Swatch  Return Nestle  Return SMI  Return SMI t-1  \
# Date
# 1998-07-21      -0.009236       0.008360    0.001333        0.013586
# 1998-07-22      -0.024603      -0.017725   -0.008476        0.001333
# 1998-07-23      -0.023474      -0.036088   -0.013368       -0.008476
# 1998-07-24       0.017809      -0.035024   -0.002856       -0.013368
# 1998-07-27      -0.015754      -0.036921   -0.025226       -0.002856
# ...                   ...            ...         ...             ...
# 2020-04-03      -0.030569       0.012663   -0.003076        0.011122
# 2020-04-06       0.073211       0.015631    0.023792       -0.003076
# 2020-04-07       0.035258      -0.000577    0.005523        0.023792
# 2020-04-08      -0.003949       0.002887   -0.008640        0.005523
# 2020-04-09      -0.004460      -0.019002    0.002167       -0.008640
#
#             Return Swatch t-1  Return Nestle t-1
# Date
# 1998-07-21           0.000000           0.010192
# 1998-07-22          -0.009236           0.008360
# 1998-07-23          -0.024603          -0.017725
# 1998-07-24          -0.023474          -0.036088
# 1998-07-27           0.017809          -0.035024
# ...                       ...                ...
# 2020-04-03           0.013743           0.012420
# 2020-04-06          -0.030569           0.012663
# 2020-04-07           0.073211           0.015631
# 2020-04-08           0.035258          -0.000577
# 2020-04-09          -0.003949           0.002887
#
# [5459 rows x 6 columns]

# %%
import statsmodels.api as sm
#2e) regress Nestle returns on the contemporaneous and lagged Index returns

y= reg_data['Return Nestle']

x= reg_data[['Return SMI','Return SMI t-1']]

x = sm.add_constant(x)
model = sm.OLS(y, x)
results = model.fit()
print(results.summary())
print(results.summary().as_latex())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Return Nestle   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     19.35
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           4.24e-09
# Time:                        18:35:24   Log-Likelihood:                 3618.1
# No. Observations:                5459   AIC:                            -7230.
# Df Residuals:                    5456   BIC:                            -7210.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0021      0.002      1.258      0.208      -0.001       0.005
# Return SMI         0.8755      0.141      6.219      0.000       0.600       1.151
# Return SMI t-1    -0.0435      0.141     -0.309      0.757      -0.319       0.232
# ==============================================================================
# Omnibus:                    19532.201   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6247935606.609
# Skew:                          71.609   Prob(JB):                         0.00
# Kurtosis:                    5242.081   Cond. No.                         84.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}    &  Return Nestle   & \textbf{  R-squared:         } &       0.007     \\
# \textbf{Model:}            &       OLS        & \textbf{  Adj. R-squared:    } &       0.007     \\
# \textbf{Method:}           &  Least Squares   & \textbf{  F-statistic:       } &       19.35     \\
# \textbf{Date:}             & Thu, 10 Dec 2020 & \textbf{  Prob (F-statistic):} &    4.24e-09     \\
# \textbf{Time:}             &     18:35:24     & \textbf{  Log-Likelihood:    } &      3618.1     \\
# \textbf{No. Observations:} &        5459      & \textbf{  AIC:               } &      -7230.     \\
# \textbf{Df Residuals:}     &        5456      & \textbf{  BIC:               } &      -7210.     \\
# \textbf{Df Model:}         &           2      & \textbf{                     } &                 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                         & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{const}          &       0.0021  &        0.002     &     1.258  &         0.208        &       -0.001    &        0.005     \\
# \textbf{Return SMI}     &       0.8755  &        0.141     &     6.219  &         0.000        &        0.600    &        1.151     \\
# \textbf{Return SMI t-1} &      -0.0435  &        0.141     &    -0.309  &         0.757        &       -0.319    &        0.232     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 19532.201 & \textbf{  Durbin-Watson:     } &       2.195     \\
# \textbf{Prob(Omnibus):} &    0.000  & \textbf{  Jarque-Bera (JB):  } & 6247935606.609  \\
# \textbf{Skew:}          &   71.609  & \textbf{  Prob(JB):          } &        0.00     \\
# \textbf{Kurtosis:}      &  5242.081 & \textbf{  Cond. No.          } &        84.6     \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Warnings: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y= reg_data['Return Swatch']

x= reg_data[['Return SMI','Return SMI t-1']]

x = sm.add_constant(x)
model = sm.OLS(y, x)
results = model.fit()
print(results.summary())
print(results.summary().as_latex())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Return Swatch   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     1698.
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):               0.00
# Time:                        18:32:52   Log-Likelihood:                 14651.
# No. Observations:                5459   AIC:                        -2.930e+04
# Df Residuals:                    5456   BIC:                        -2.928e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0003      0.000      1.343      0.179      -0.000       0.001
# Return SMI         1.0870      0.019     58.269      0.000       1.050       1.124
# Return SMI t-1    -0.0111      0.019     -0.597      0.551      -0.048       0.025
# ==============================================================================
# Omnibus:                      552.133   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3940.212
# Skew:                           0.188   Prob(JB):                         0.00
# Kurtosis:                       7.145   Cond. No.                         84.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}    &  Return Swatch   & \textbf{  R-squared:         } &     0.384   \\
# \textbf{Model:}            &       OLS        & \textbf{  Adj. R-squared:    } &     0.383   \\
# \textbf{Method:}           &  Least Squares   & \textbf{  F-statistic:       } &     1698.   \\
# \textbf{Date:}             & Thu, 10 Dec 2020 & \textbf{  Prob (F-statistic):} &     0.00    \\
# \textbf{Time:}             &     18:32:52     & \textbf{  Log-Likelihood:    } &    14651.   \\
# \textbf{No. Observations:} &        5459      & \textbf{  AIC:               } & -2.930e+04  \\
# \textbf{Df Residuals:}     &        5456      & \textbf{  BIC:               } & -2.928e+04  \\
# \textbf{Df Model:}         &           2      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                         & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{const}          &       0.0003  &        0.000     &     1.343  &         0.179        &       -0.000    &        0.001     \\
# \textbf{Return SMI}     &       1.0870  &        0.019     &    58.269  &         0.000        &        1.050    &        1.124     \\
# \textbf{Return SMI t-1} &      -0.0111  &        0.019     &    -0.597  &         0.551        &       -0.048    &        0.025     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 552.133 & \textbf{  Durbin-Watson:     } &    1.961  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } & 3940.212  \\
# \textbf{Skew:}          &   0.188 & \textbf{  Prob(JB):          } &     0.00  \\
# \textbf{Kurtosis:}      &   7.145 & \textbf{  Cond. No.          } &     84.6  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Warnings: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
